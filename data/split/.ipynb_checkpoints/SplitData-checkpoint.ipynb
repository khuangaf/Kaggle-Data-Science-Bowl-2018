# %%
import numpy as np
import os

# %%
np.random.seed(42)

# %%
with open("train1_ids_all_670", "r") as f:
    train_ids_all = [l.strip() for l in f]

# %%
train_ids_all
# Out:
# ['stage1_train/00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552',
#  'stage1_train/003cee89357d9fe13516167fd67b609a164651b21934585648c740d2c3d86dc1',
#  'stage1_train/00ae65c1c6631ae6f2be1a449902976e6eb8483bf6b0740d00530220832c6d3e',
#  'stage1_train/0121d6759c5adb290c8e828fc882f37dfaf3663ec885c663859948c154a443ed',
#  'stage1_train/01d44a26f6680c42ba94c9bc6339228579a95d0e2695b149b7cc0c9592b21baf',
#  'stage1_train/0280fa8f60f6bcae0f97d93c28f60be194f9309ff610dc5845e60455b0f87c21',
#  'stage1_train/0287e7ee5b007c91ae2bd7628d09735e70496bc6127ecb7f3dd043e04ce37426',
#  'stage1_train/02903040e19ddf92f452907644ad3822918f54af41dd85e5a3fe3e1b6d6f9339',
#  'stage1_train/03398329ced0c23b9ac3fac84dd53a87d9ffe4d9d10f1b5fe8df8fac12380776',
#  'stage1_train/03b9306f44e9b8951461623dcbd615550cdcf36ea93b203f2c8fa58ed1dffcbe',
#  'stage1_train/03f583ec5018739f4abb9b3b4a580ac43bd933c4337ad8877aa18b1dfb59fc9a',
# ...

# %%
with open("train1_ids_gray2_500", "r") as f:
    train_ids_gray = [l.strip() for l in f]

# %%
with open("valid1_ids_gray2_43", "r") as f:
    valid_ids_gray = [l.strip() for l in f]

# %%
all_gray = train_ids_gray + valid_ids_gray
len(all_gray)
# Out:
# 543

# %%
all_colored = list(set(train_ids_all) - set(all_gray))
len(all_colored)
# Out:
# 128

# %%
np.random.shuffle(all_colored)

# %%
num_train = 100

# %%
with open("train1_ids_colored_100", "r") as f:
    split_train_color_ids = [l.strip() for l in f]
len(split_train_color_ids)
# Out:
# 100

# %%
len(split_train_color_ids), len(split_val_color_ids)
# Out:
# (100, 28)

# %%
extenal_ids = ['external/'+im_name for im_name in os.listdir('/data/steeve/DSB/data/__download__/extra_data/extra_data/')]
extenal_ids
# Out:
# ['external/TCGA-18-5592-01Z-00-DX1',
#  'external/TCGA-21-5784-01Z-00-DX1',
#  'external/TCGA-21-5786-01Z-00-DX1',
#  'external/TCGA-38-6178-01Z-00-DX1',
#  'external/TCGA-49-4488-01Z-00-DX1',
#  'external/TCGA-50-5931-01Z-00-DX1',
#  'external/TCGA-A7-A13E-01Z-00-DX1',
#  'external/TCGA-A7-A13F-01Z-00-DX1',
#  'external/TCGA-AR-A1AK-01Z-00-DX1',
#  'external/TCGA-AR-A1AS-01Z-00-DX1',
#  'external/TCGA-AY-A8YK-01A-01-TS1',
#  'external/TCGA-B0-5698-01Z-00-DX1',
#  'external/TCGA-B0-5710-01Z-00-DX1',
#  'external/TCGA-B0-5711-01Z-00-DX1',
#  'external/TCGA-CH-5767-01Z-00-DX1',
#  'external/TCGA-DK-A2I6-01A-01-TS1',
#  'external/TCGA-E2-A14V-01Z-00-DX1',
#  'external/TCGA-E2-A1B5-01Z-00-DX1',
#  'external/TCGA-G2-A2EK-01A-02-TSB',
#  'external/TCGA-G9-6336-01Z-00-DX1',
#  'external/TCGA-G9-6348-01Z-00-DX1',
#  'external/TCGA-G9-6356-01Z-00-DX1',
#  'external/TCGA-G9-6362-01Z-00-DX1',
#  'external/TCGA-G9-6363-01Z-00-DX1',
#  'external/TCGA-HE-7128-01Z-00-DX1',
# ...

# %%
len(extenal_ids)
# Out:
# 30

# %%
with open('external_ids_colored_30', 'w') as f:
    for item in extenal_ids:
          f.write("%s\n" % item)

# %%
split_train_external_color_ids = split_train_color_ids +  extenal_ids
len(split_train_external_color_ids)
# Out:
# 130

# %%
with open('train1_external_ids_colored_130', 'w') as f:
    for item in split_train_external_color_ids:
          f.write("%s\n" % item)

# %%
split_train_ids = split_train_ids + extenal_ids
len(split_train_ids)
# Out:
# 770

# %%
with open('train1_ids_colored_110', 'w') as f:
    for item in split_train_ids:
          f.write("%s\n" % item)

# %%
with open('valid1_ids_colored_18', 'w') as f:
    for item in split_val_ids:
          f.write("%s\n" % item)

# %%
num_train = 600

# %%
split_train_ids = train_ids[:num_train]
split_val_ids = train_ids[num_train:]

# %%
len(split_train_ids),len(split_val_ids)
# Out:
# (600, 70)

# %%
with open('train1_ids_colored_', 'w') as f:
    for item in split_train_ids:
          f.write("%s\n" % item)

# %%
with open('valid1_ids_mixed_70', 'w') as f:
    for item in split_val_ids:
          f.write("%s\n" % item)

# %% [markdown]
# ## Split Test

# %%
with open("test1_ids_all_65", "r") as f:
    test_ids_all = [l.strip() for l in f]

# %%
with open("test1_ids_gray_only_53", "r") as f:
    test_ids_gray = [l.strip() for l in f]

# %%
test_ids_color = list(set(test_ids_all) - set(test_ids_gray))
len(test_ids_color)
# Out:
# 12

# %%
with open('test1_ids_color_12', 'w') as f:
    for item in test_ids_color:
          f.write("%s\n" % item)

# %% [markdown]
# ## Fill missing tests

# %%
import pandas as pd

# %%
df = pd.read_csv('/data/steeve/DSB/results/mask-rcnn-50-gray500-02/submit/mixed_65.csv')

# %%
test_ids_all_clean = [ t_id.split('/')[1] for t_id in test_ids_all]

# %%
count= 0
for t_id in test_ids_all_clean:
    
    if t_id not in set(df.ImageId):
        count+=1
        print(t_id)
print(count)
# Out:
# 0f1f896d9ae5a04752d3239c690402c022db4d72c0d2c087d73380896f72c466
# 17b9bf4356db24967c4677b8376ac38f826de73a88b93a8d73a8b452e399cdff
# 1d9eacb3161f1e2b45550389ecf7c535c7199c6b44b1c6a46303f7b965e508f1
# 259b35151d4a7a5ffdd7ab7f171b142db8cfe40beeee67277fac6adca4d042c4
# 3c4c675825f7509877bc10497f498c9a2e3433bf922bd870914a2eb21a54fd26
# 44afae184c89e6ba55985b4d341acc1ae1e8b6ef96312064e0e6e630e022b078
# 472b1c5ff988dadc209faea92499bc07f305208dbda29d16262b3d543ac91c71
# 9f17aea854db13015d19b34cb2022cfdeda44133323fcd6bb3545f7b9404d8ab
# b83d1d77935b6cfd44105b54600ffc4b6bd82de57dec65571bcb117fa8398ba3
# c8e79ff4ac55f4b772057de28e539727b7f4f2a3de73bf7a082a0ace86d609eb
# da6c593410340b19bb212b9f6d274f95b08c0fc8f2570cd66bc5ed42c560acab
# f5effed21f671bbf4551ecebb7fe95f3be1cf09c16a60afe64d2f0b95be9d1eb
# 12

# %%
df.ImageId.unique.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-c220f1f566d8> in <module>()
# ----> 1 df.ImageId.unique.shape
#
# AttributeError: 'function' object has no attribute 'shape'

# %%
df.ImageId[0]
# Out:
# '0114f484a16c152baa2d82fdd43740880a762c93f436c8988ac461c5c9dbe7d5'

# %%
with open('test1_ids_color_12') as f:
    tids = ['/data/steeve/DSB/data/image/stage1_test/images/'+l.strip().split('/')[1]+'.png' for l in f]

# %%
import cv2

# %%
im = cv2.imread(tids[0])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
for tid in tids:
    print(f'{tid}')
    plt.imshow(cv2.imread(tid))

    plt.show()
# Out:
# /data/steeve/DSB/data/image/stage1_test/images/c8e79ff4ac55f4b772057de28e539727b7f4f2a3de73bf7a082a0ace86d609eb.png
# /data/steeve/DSB/data/image/stage1_test/images/9f17aea854db13015d19b34cb2022cfdeda44133323fcd6bb3545f7b9404d8ab.png
# /data/steeve/DSB/data/image/stage1_test/images/0f1f896d9ae5a04752d3239c690402c022db4d72c0d2c087d73380896f72c466.png
# /data/steeve/DSB/data/image/stage1_test/images/da6c593410340b19bb212b9f6d274f95b08c0fc8f2570cd66bc5ed42c560acab.png
# /data/steeve/DSB/data/image/stage1_test/images/472b1c5ff988dadc209faea92499bc07f305208dbda29d16262b3d543ac91c71.png
# /data/steeve/DSB/data/image/stage1_test/images/259b35151d4a7a5ffdd7ab7f171b142db8cfe40beeee67277fac6adca4d042c4.png
# /data/steeve/DSB/data/image/stage1_test/images/f5effed21f671bbf4551ecebb7fe95f3be1cf09c16a60afe64d2f0b95be9d1eb.png
# /data/steeve/DSB/data/image/stage1_test/images/b83d1d77935b6cfd44105b54600ffc4b6bd82de57dec65571bcb117fa8398ba3.png
# ...
